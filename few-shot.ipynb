# %%
# !git clone --single-branch --branch B https://github.com/VCoklat/Few-Shot-Cosine-Transformer.git
# !pip install -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt
# %cd /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/
# !source download_miniImagenet.sh
# %cd ../../../
# %cd /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/
# Out:
# Cloning into 'Few-Shot-Cosine-Transformer'...
# remote: Enumerating objects: 330454, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 330454 (delta 70), reused 51 (delta 48), pack-reused 330371 (from 2)
# Receiving objects: 100% (330454/330454), 2.41 GiB | 41.12 MiB/s, done.
# Resolving deltas: 100% (304/304), done.
# Updating files: 100% (296648/296648), done.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 3)) (0.20.1+cu121)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 6)) (3.12.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (3.7.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 10)) (11.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (0.19.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.11.0a2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (1.3.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (4.0.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2024.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (5.0.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2024.2.0)
# /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet
# --2025-04-12 06:37:35--  https://raw.githubusercontent.com/twitter/meta-learning-lstm/master/data/miniImagenet/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1228815 (1.2M) [text/plain]
# Saving to: ‘train.csv.1’
#
# train.csv.1         100%[===================>]   1.17M  --.-KB/s    in 0.02s
#
# 2025-04-12 06:37:35 (58.6 MB/s) - ‘train.csv.1’ saved [1228815/1228815]
#
# --2025-04-12 06:37:35--  https://raw.githubusercontent.com/twitter/meta-learning-lstm/master/data/miniImagenet/val.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 307215 (300K) [text/plain]
# Saving to: ‘val.csv.1’
#
# val.csv.1           100%[===================>] 300.01K  --.-KB/s    in 0.01s
#
# 2025-04-12 06:37:35 (23.7 MB/s) - ‘val.csv.1’ saved [307215/307215]
#
# --2025-04-12 06:37:35--  https://raw.githubusercontent.com/twitter/meta-learning-lstm/master/data/miniImagenet/test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384015 (375K) [text/plain]
# Saving to: ‘test.csv.1’
#
# test.csv.1          100%[===================>] 375.01K  --.-KB/s    in 0.01s
#
# 2025-04-12 06:37:36 (26.9 MB/s) - ‘test.csv.1’ saved [384015/384015]
#
# /kaggle/working
# /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet

# %%
import numpy as np
from os import listdir
from os.path import isfile, isdir, join
import os
import json
import random
import re

cwd = os.getcwd()
data_path = '/kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/image/'
savedir = './'
dataset_list = ['base', 'val', 'novel']

cl = -1
folderlist = []  # to store label??

datasetmap = {'base': 'train', 'val': 'val', 'novel': 'test'}

filelists = {'base': {}, 'val': {}, 'novel': {}}
filelists_flat = {'base': [], 'val': [], 'novel': []}
labellists_flat = {'base': [], 'val': [], 'novel': []}

for dataset in dataset_list:
    with open(datasetmap[dataset] + ".csv", "r") as lines:
        for i, line in enumerate(lines):
            if i == 0:
                continue
            fid, _, label = re.split(',|\.', line)
            label = label.replace('\n', '')
            if not label in filelists[dataset]:
                folderlist.append(label)
                filelists[dataset][label] = []  # new label
                fnames = listdir(join(data_path, label))
            name = fid + '.jpg'
            fname = join(data_path, label, name)
            filelists[dataset][label].append(fname)

    for key, filelist in filelists[dataset].items():
        cl += 1
        random.shuffle(filelist)
        filelists_flat[dataset] += filelist
        labellists_flat[dataset] += np.repeat(cl, len(filelist)).tolist()

for dataset in dataset_list:
    fo = open(savedir + dataset + ".json", "w")
    fo.write('{"label_names": [')
    fo.writelines(['"%s",' % item for item in folderlist])
    fo.seek(0, os.SEEK_END)
    fo.seek(fo.tell()-1, os.SEEK_SET)
    fo.write('],')

    fo.write('"image_names": [')
    fo.writelines(['"%s",' % item for item in filelists_flat[dataset]])
    fo.seek(0, os.SEEK_END)
    fo.seek(fo.tell()-1, os.SEEK_SET)
    fo.write('],')

    fo.write('"image_labels": [')
    fo.writelines(['%d,' % item for item in labellists_flat[dataset]])
    fo.seek(0, os.SEEK_END)
    fo.seek(fo.tell()-1, os.SEEK_SET)
    fo.write(']}')

    fo.close()
    print("%s -OK" % dataset)
# Out:
# base -OK
# val -OK
# novel -OK

# %%
import numpy as np
from os import listdir
from os.path import isfile, isdir, join
import os
import json
import random
import re

cwd = os.getcwd()
data_path = '/kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/image/'
savedir = './'
dataset_list = ['base', 'val', 'novel']


cl = -1
folderlist = []

datasetmap = {'base': 'train', 'val': 'val', 'novel': 'test'}
filelists = {'base': {}, 'val': {}, 'novel': {}}
filelists_flat = {'base': [], 'val': [], 'novel': []}
labellists_flat = {'base': [], 'val': [], 'novel': []}

for dataset in dataset_list:
    with open(datasetmap[dataset] + ".csv", "r") as lines:
        for i, line in enumerate(lines):
            if i == 0:
                continue
            fid, _, label = re.split(',|\.', line)
            label = label.replace('\n', '')
            if not label in filelists[dataset]:
                folderlist.append(label)
                filelists[dataset][label] = []
                fnames = listdir(join(data_path, label))
            name = fid + '.jpg'
            fname = join(data_path, label, name)
            filelists[dataset][label].append(fname)

    for key, filelist in filelists[dataset].items():
        cl += 1
        random.shuffle(filelist)
        filelists_flat[dataset] += filelist
        labellists_flat[dataset] += np.repeat(cl, len(filelist)).tolist()

# cross setting use base/val/novel together
filelists_flat_all = filelists_flat['base'] + \
    filelists_flat['val'] + filelists_flat['novel']
labellists_flat_all = labellists_flat['base'] + \
    labellists_flat['val'] + labellists_flat['novel']
fo = open(savedir + "all.json", "w")
fo.write('{"label_names": [')
fo.writelines(['"%s",' % item for item in folderlist])
fo.seek(0, os.SEEK_END)
fo.seek(fo.tell()-1, os.SEEK_SET)
fo.write('],')

fo.write('"image_names": [')
fo.writelines(['"%s",' % item for item in filelists_flat_all])
fo.seek(0, os.SEEK_END)
fo.seek(fo.tell()-1, os.SEEK_SET)
fo.write('],')

fo.write('"image_labels": [')
fo.writelines(['%d,' % item for item in labellists_flat_all])
fo.seek(0, os.SEEK_END)
fo.seek(fo.tell()-1, os.SEEK_SET)
fo.write(']}')

fo.close()
print("all -OK")
# Out:
# all -OK

# %%
# %cd ../../
# Out:
# /kaggle/working/Few-Shot-Cosine-Transformer

# %%
# !python train_test.py --method FSCT_cosine --dataset miniImagenet --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 200 --test_iter 200
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'miniImagenet',
#     'datetime': '20250412@063747',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 200,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 200,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 22.381250  | Loss 1.627759: 100%|█| 200/200 [03:24<00:00,  1
# Validation    | Acc 21.868750: 100%|██████████| 200/200 [00:53<00:00,  3.73it/s]
# Val Acc = 21.87% +- 0.51%
# best model! save...
#
# Epoch 002/050 | Acc 21.862500  | Loss 1.606973: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 20.856250: 100%|██████████| 200/200 [00:53<00:00,  3.70it/s]
# Val Acc = 20.86% +- 0.77%
#
# Epoch 003/050 | Acc 20.968750  | Loss 1.609585: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 21.137500: 100%|██████████| 200/200 [00:53<00:00,  3.73it/s]
# Val Acc = 21.14% +- 0.51%
#
# Epoch 004/050 | Acc 22.037500  | Loss 1.607209: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 23.256250: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 23.26% +- 0.59%
# best model! save...
#
# Epoch 005/050 | Acc 24.412500  | Loss 1.598874: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 27.368750: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 27.37% +- 0.80%
# best model! save...
#
# Epoch 006/050 | Acc 27.762500  | Loss 1.568315: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 28.500000: 100%|██████████| 200/200 [00:53<00:00,  3.72it/s]
# Val Acc = 28.50% +- 0.72%
# best model! save...
#
# Epoch 007/050 | Acc 31.625000  | Loss 1.526711: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 32.100000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 32.10% +- 1.00%
# best model! save...
#
# Epoch 008/050 | Acc 35.656250  | Loss 1.465222: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 34.893750: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 34.89% +- 0.90%
# best model! save...
#
# Epoch 009/050 | Acc 38.012500  | Loss 1.430287: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 34.950000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 34.95% +- 1.00%
# best model! save...
#
# Epoch 010/050 | Acc 40.825000  | Loss 1.391012: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 36.793750: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 36.79% +- 0.98%
# best model! save...
#
# Epoch 011/050 | Acc 40.575000  | Loss 1.396292: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 35.375000: 100%|██████████| 200/200 [00:53<00:00,  3.70it/s]
# Val Acc = 35.38% +- 0.93%
#
# Epoch 012/050 | Acc 44.925000  | Loss 1.322299: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 36.375000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 36.38% +- 1.02%
#
# Epoch 013/050 | Acc 44.681250  | Loss 1.321737: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 39.143750: 100%|██████████| 200/200 [00:54<00:00,  3.69it/s]
# Val Acc = 39.14% +- 1.01%
# best model! save...
#
# Epoch 014/050 | Acc 48.025000  | Loss 1.262587: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 38.475000: 100%|██████████| 200/200 [00:54<00:00,  3.67it/s]
# Val Acc = 38.48% +- 0.94%
#
# Epoch 015/050 | Acc 48.893750  | Loss 1.243699: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 37.587500: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 37.59% +- 1.03%
#
# Epoch 016/050 | Acc 51.081250  | Loss 1.209710: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 43.168750: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 43.17% +- 1.00%
# best model! save...
#
# Epoch 017/050 | Acc 52.531250  | Loss 1.162676: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 41.562500: 100%|██████████| 200/200 [00:53<00:00,  3.72it/s]
# Val Acc = 41.56% +- 0.94%
#
# Epoch 018/050 | Acc 53.956250  | Loss 1.139614: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 44.918750: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 44.92% +- 1.10%
# best model! save...
#
# Epoch 019/050 | Acc 57.275000  | Loss 1.087413: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 48.168750: 100%|██████████| 200/200 [00:53<00:00,  3.72it/s]
# Val Acc = 48.17% +- 1.22%
# best model! save...
#
# Epoch 020/050 | Acc 57.293750  | Loss 1.078484: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 48.481250: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 48.48% +- 1.15%
# best model! save...
#
# Epoch 021/050 | Acc 60.043750  | Loss 1.010950: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 47.843750: 100%|██████████| 200/200 [00:53<00:00,  3.72it/s]
# Val Acc = 47.84% +- 1.09%
#
# Epoch 022/050 | Acc 61.256250  | Loss 0.995153: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 50.825000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 50.83% +- 1.14%
# best model! save...
#
# Epoch 023/050 | Acc 63.037500  | Loss 0.956867: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 51.443750: 100%|██████████| 200/200 [00:54<00:00,  3.69it/s]
# Val Acc = 51.44% +- 1.18%
# best model! save...
#
# Epoch 024/050 | Acc 62.906250  | Loss 0.947631: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 51.218750: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 51.22% +- 1.29%
#
# Epoch 025/050 | Acc 64.962500  | Loss 0.904439: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 52.943750: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 52.94% +- 1.20%
# best model! save...
#
# Epoch 026/050 | Acc 67.281250  | Loss 0.842449: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 53.950000: 100%|██████████| 200/200 [00:54<00:00,  3.68it/s]
# Val Acc = 53.95% +- 1.18%
# best model! save...
#
# Epoch 027/050 | Acc 67.043750  | Loss 0.847848: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 52.712500: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 52.71% +- 1.15%
#
# Epoch 028/050 | Acc 67.937500  | Loss 0.827084: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 52.531250: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 52.53% +- 1.22%
#
# Epoch 029/050 | Acc 68.506250  | Loss 0.821102: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 56.318750: 100%|██████████| 200/200 [00:54<00:00,  3.69it/s]
# Val Acc = 56.32% +- 1.18%
# best model! save...
#
# Epoch 030/050 | Acc 68.406250  | Loss 0.810678: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 55.987500: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 55.99% +- 1.17%
#
# Epoch 031/050 | Acc 71.156250  | Loss 0.757099: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 55.906250: 100%|██████████| 200/200 [00:54<00:00,  3.69it/s]
# Val Acc = 55.91% +- 1.16%
#
# Epoch 032/050 | Acc 71.537500  | Loss 0.744057: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 55.118750: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 55.12% +- 1.24%
#
# Epoch 033/050 | Acc 72.000000  | Loss 0.735584: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 56.425000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 56.42% +- 1.24%
# best model! save...
#
# Epoch 034/050 | Acc 72.300000  | Loss 0.716399: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 57.143750: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 57.14% +- 1.13%
# best model! save...
#
# Epoch 035/050 | Acc 74.218750  | Loss 0.678040: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 58.037500: 100%|██████████| 200/200 [00:54<00:00,  3.68it/s]
# Val Acc = 58.04% +- 1.30%
# best model! save...
#
# Epoch 036/050 | Acc 73.762500  | Loss 0.679263: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 59.075000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 59.08% +- 1.16%
# best model! save...
#
# Epoch 037/050 | Acc 75.625000  | Loss 0.643834: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 55.606250: 100%|██████████| 200/200 [00:53<00:00,  3.72it/s]
# Val Acc = 55.61% +- 1.25%
#
# Epoch 038/050 | Acc 75.143750  | Loss 0.651445: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 57.956250: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 57.96% +- 1.12%
#
# Epoch 039/050 | Acc 76.100000  | Loss 0.622010: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 58.618750: 100%|██████████| 200/200 [00:53<00:00,  3.72it/s]
# Val Acc = 58.62% +- 1.07%
#
# Epoch 040/050 | Acc 75.362500  | Loss 0.641931: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 57.950000: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 57.95% +- 1.27%
#
# Epoch 041/050 | Acc 76.956250  | Loss 0.596609: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 57.768750: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 57.77% +- 1.28%
#
# Epoch 042/050 | Acc 76.687500  | Loss 0.604962: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 58.431250: 100%|██████████| 200/200 [00:54<00:00,  3.68it/s]
# Val Acc = 58.43% +- 1.16%
#
# Epoch 043/050 | Acc 78.793750  | Loss 0.557517: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 59.150000: 100%|██████████| 200/200 [00:54<00:00,  3.69it/s]
# Val Acc = 59.15% +- 1.24%
# best model! save...
#
# Epoch 044/050 | Acc 78.693750  | Loss 0.564216: 100%|█| 200/200 [03:21<00:00,  1
# Validation    | Acc 58.706250: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 58.71% +- 1.24%
#
# Epoch 045/050 | Acc 80.412500  | Loss 0.515439: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 59.993750: 100%|██████████| 200/200 [00:54<00:00,  3.69it/s]
# Val Acc = 59.99% +- 1.26%
# best model! save...
#
# Epoch 046/050 | Acc 80.325000  | Loss 0.520554: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 61.231250: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 61.23% +- 1.23%
# best model! save...
#
# Epoch 047/050 | Acc 80.643750  | Loss 0.506483: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 59.368750: 100%|██████████| 200/200 [00:54<00:00,  3.70it/s]
# Val Acc = 59.37% +- 1.17%
#
# Epoch 048/050 | Acc 81.856250  | Loss 0.475026: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 60.106250: 100%|██████████| 200/200 [00:53<00:00,  3.71it/s]
# Val Acc = 60.11% +- 1.22%
#
# Epoch 049/050 | Acc 82.531250  | Loss 0.458366: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 58.687500: 100%|██████████| 200/200 [00:54<00:00,  3.67it/s]
# Val Acc = 58.69% +- 1.21%
#
# Epoch 050/050 | Acc 83.131250  | Loss 0.444465: 100%|█| 200/200 [03:22<00:00,  1
# Validation    | Acc 58.762500: 100%|██████████| 200/200 [00:54<00:00,  3.68it/s]
# Val Acc = 58.76% +- 1.31%
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/novel.json
# Test loader contains 200 episodes
# Test       | Acc 20.000000: 100%|█████████████| 200/200 [00:55<00:00,  3.58it/s]
# 200 Test Acc = 20.00% +- 0.00%

# %%
# !python train_test.py --method FSCT_cosine --dataset CIFAR --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 200 --test_iter 200
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'CIFAR',
#     'datetime': '20250412@101239',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 200,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 200,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 34.137500  | Loss 1.498080: 100%|█| 200/200 [00:58<00:00,  3
# Validation    | Acc 31.637500: 100%|██████████| 200/200 [00:18<00:00, 10.95it/s]
# Val Acc = 31.64% +- 1.08%
# best model! save...
#
# Epoch 002/050 | Acc 40.731250  | Loss 1.392079: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 35.443750: 100%|██████████| 200/200 [00:18<00:00, 10.81it/s]
# Val Acc = 35.44% +- 1.00%
# best model! save...
#
# Epoch 003/050 | Acc 45.968750  | Loss 1.297737: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 37.900000: 100%|██████████| 200/200 [00:18<00:00, 10.80it/s]
# Val Acc = 37.90% +- 1.17%
# best model! save...
#
# Epoch 004/050 | Acc 47.175000  | Loss 1.274116: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 40.493750: 100%|██████████| 200/200 [00:18<00:00, 11.04it/s]
# Val Acc = 40.49% +- 1.20%
# best model! save...
#
# Epoch 005/050 | Acc 52.412500  | Loss 1.171317: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 44.325000: 100%|██████████| 200/200 [00:18<00:00, 10.69it/s]
# Val Acc = 44.33% +- 1.09%
# best model! save...
#
# Epoch 006/050 | Acc 53.631250  | Loss 1.134624: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 45.143750: 100%|██████████| 200/200 [00:18<00:00, 10.85it/s]
# Val Acc = 45.14% +- 1.25%
# best model! save...
#
# Epoch 007/050 | Acc 57.868750  | Loss 1.056667: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 48.500000: 100%|██████████| 200/200 [00:18<00:00, 10.92it/s]
# Val Acc = 48.50% +- 1.34%
# best model! save...
#
# Epoch 008/050 | Acc 58.412500  | Loss 1.029100: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 53.818750: 100%|██████████| 200/200 [00:18<00:00, 10.94it/s]
# Val Acc = 53.82% +- 1.38%
# best model! save...
#
# Epoch 009/050 | Acc 61.512500  | Loss 0.959705: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 53.125000: 100%|██████████| 200/200 [00:18<00:00, 10.77it/s]
# Val Acc = 53.12% +- 1.33%
#
# Epoch 010/050 | Acc 62.037500  | Loss 0.947590: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 56.550000: 100%|██████████| 200/200 [00:18<00:00, 10.84it/s]
# Val Acc = 56.55% +- 1.43%
# best model! save...
#
# Epoch 011/050 | Acc 63.518750  | Loss 0.907578: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 57.268750: 100%|██████████| 200/200 [00:18<00:00, 10.97it/s]
# Val Acc = 57.27% +- 1.42%
# best model! save...
#
# Epoch 012/050 | Acc 65.518750  | Loss 0.858072: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 55.000000: 100%|██████████| 200/200 [00:18<00:00, 10.54it/s]
# Val Acc = 55.00% +- 1.38%
#
# Epoch 013/050 | Acc 66.206250  | Loss 0.855350: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 57.412500: 100%|██████████| 200/200 [00:18<00:00, 10.90it/s]
# Val Acc = 57.41% +- 1.51%
# best model! save...
#
# Epoch 014/050 | Acc 69.587500  | Loss 0.777710: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 59.000000: 100%|██████████| 200/200 [00:18<00:00, 10.87it/s]
# Val Acc = 59.00% +- 1.39%
# best model! save...
#
# Epoch 015/050 | Acc 69.306250  | Loss 0.780758: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 58.025000: 100%|██████████| 200/200 [00:19<00:00, 10.34it/s]
# Val Acc = 58.02% +- 1.34%
#
# Epoch 016/050 | Acc 71.812500  | Loss 0.725438: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 57.900000: 100%|██████████| 200/200 [00:18<00:00, 10.88it/s]
# Val Acc = 57.90% +- 1.33%
#
# Epoch 017/050 | Acc 71.812500  | Loss 0.725322: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 57.387500: 100%|██████████| 200/200 [00:18<00:00, 10.67it/s]
# Val Acc = 57.39% +- 1.42%
#
# Epoch 018/050 | Acc 71.981250  | Loss 0.706636: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 58.756250: 100%|██████████| 200/200 [00:18<00:00, 10.71it/s]
# Val Acc = 58.76% +- 1.29%
#
# Epoch 019/050 | Acc 72.106250  | Loss 0.710264: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 60.762500: 100%|██████████| 200/200 [00:18<00:00, 10.98it/s]
# Val Acc = 60.76% +- 1.45%
# best model! save...
#
# Epoch 020/050 | Acc 75.850000  | Loss 0.630298: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 62.406250: 100%|██████████| 200/200 [00:19<00:00, 10.48it/s]
# Val Acc = 62.41% +- 1.42%
# best model! save...
#
# Epoch 021/050 | Acc 75.831250  | Loss 0.618271: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 62.075000: 100%|██████████| 200/200 [00:18<00:00, 10.75it/s]
# Val Acc = 62.08% +- 1.37%
#
# Epoch 022/050 | Acc 75.218750  | Loss 0.632665: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 63.018750: 100%|██████████| 200/200 [00:18<00:00, 10.78it/s]
# Val Acc = 63.02% +- 1.38%
# best model! save...
#
# Epoch 023/050 | Acc 77.618750  | Loss 0.568441: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 64.368750: 100%|██████████| 200/200 [00:18<00:00, 10.80it/s]
# Val Acc = 64.37% +- 1.26%
# best model! save...
#
# Epoch 024/050 | Acc 77.768750  | Loss 0.578715: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 64.037500: 100%|██████████| 200/200 [00:18<00:00, 10.80it/s]
# Val Acc = 64.04% +- 1.37%
#
# Epoch 025/050 | Acc 80.243750  | Loss 0.529361: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 64.137500: 100%|██████████| 200/200 [00:19<00:00, 10.49it/s]
# Val Acc = 64.14% +- 1.32%
#
# Epoch 026/050 | Acc 80.325000  | Loss 0.518523: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 62.743750: 100%|██████████| 200/200 [00:18<00:00, 10.76it/s]
# Val Acc = 62.74% +- 1.57%
#
# Epoch 027/050 | Acc 80.000000  | Loss 0.515855: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 66.350000: 100%|██████████| 200/200 [00:18<00:00, 10.90it/s]
# Val Acc = 66.35% +- 1.43%
# best model! save...
#
# Epoch 028/050 | Acc 81.106250  | Loss 0.493077: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 65.875000: 100%|██████████| 200/200 [00:18<00:00, 10.71it/s]
# Val Acc = 65.88% +- 1.41%
#
# Epoch 029/050 | Acc 80.906250  | Loss 0.499393: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 64.725000: 100%|██████████| 200/200 [00:18<00:00, 10.82it/s]
# Val Acc = 64.72% +- 1.43%
#
# Epoch 030/050 | Acc 82.256250  | Loss 0.457361: 100%|█| 200/200 [00:58<00:00,  3
# Validation    | Acc 64.725000: 100%|██████████| 200/200 [00:19<00:00, 10.38it/s]
# Val Acc = 64.72% +- 1.30%
#
# Epoch 031/050 | Acc 82.043750  | Loss 0.465116: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 67.875000: 100%|██████████| 200/200 [00:18<00:00, 10.62it/s]
# Val Acc = 67.88% +- 1.31%
# best model! save...
#
# Epoch 032/050 | Acc 85.693750  | Loss 0.386551: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 67.981250: 100%|██████████| 200/200 [00:18<00:00, 10.94it/s]
# Val Acc = 67.98% +- 1.26%
# best model! save...
#
# Epoch 033/050 | Acc 84.068750  | Loss 0.407281: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 70.062500: 100%|██████████| 200/200 [00:18<00:00, 10.77it/s]
# Val Acc = 70.06% +- 1.31%
# best model! save...
#
# Epoch 034/050 | Acc 84.331250  | Loss 0.411883: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 66.293750: 100%|██████████| 200/200 [00:18<00:00, 10.85it/s]
# Val Acc = 66.29% +- 1.26%
#
# Epoch 035/050 | Acc 84.556250  | Loss 0.408390: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 66.993750: 100%|██████████| 200/200 [00:19<00:00, 10.52it/s]
# Val Acc = 66.99% +- 1.42%
#
# Epoch 036/050 | Acc 84.737500  | Loss 0.397380: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 66.081250: 100%|██████████| 200/200 [00:18<00:00, 10.64it/s]
# Val Acc = 66.08% +- 1.39%
#
# Epoch 037/050 | Acc 86.581250  | Loss 0.354938: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 67.237500: 100%|██████████| 200/200 [00:18<00:00, 10.95it/s]
# Val Acc = 67.24% +- 1.42%
#
# Epoch 038/050 | Acc 85.362500  | Loss 0.380377: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 67.106250: 100%|██████████| 200/200 [00:18<00:00, 10.84it/s]
# Val Acc = 67.11% +- 1.40%
#
# Epoch 039/050 | Acc 87.087500  | Loss 0.341961: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 70.081250: 100%|██████████| 200/200 [00:18<00:00, 10.67it/s]
# Val Acc = 70.08% +- 1.29%
# best model! save...
#
# Epoch 040/050 | Acc 87.081250  | Loss 0.346112: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 69.350000: 100%|██████████| 200/200 [00:18<00:00, 10.65it/s]
# Val Acc = 69.35% +- 1.38%
#
# Epoch 041/050 | Acc 88.087500  | Loss 0.311281: 100%|█| 200/200 [00:58<00:00,  3
# Validation    | Acc 68.531250: 100%|██████████| 200/200 [00:18<00:00, 10.72it/s]
# Val Acc = 68.53% +- 1.32%
#
# Epoch 042/050 | Acc 88.181250  | Loss 0.306533: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 67.568750: 100%|██████████| 200/200 [00:18<00:00, 10.95it/s]
# Val Acc = 67.57% +- 1.37%
#
# Epoch 043/050 | Acc 88.500000  | Loss 0.298418: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 67.893750: 100%|██████████| 200/200 [00:18<00:00, 10.85it/s]
# Val Acc = 67.89% +- 1.39%
#
# Epoch 044/050 | Acc 89.606250  | Loss 0.272060: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 68.018750: 100%|██████████| 200/200 [00:18<00:00, 10.60it/s]
# Val Acc = 68.02% +- 1.31%
#
# Epoch 045/050 | Acc 89.318750  | Loss 0.278773: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 69.506250: 100%|██████████| 200/200 [00:18<00:00, 10.60it/s]
# Val Acc = 69.51% +- 1.27%
#
# Epoch 046/050 | Acc 90.400000  | Loss 0.255726: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 69.212500: 100%|██████████| 200/200 [00:20<00:00,  9.91it/s]
# Val Acc = 69.21% +- 1.34%
#
# Epoch 047/050 | Acc 89.406250  | Loss 0.277243: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 69.212500: 100%|██████████| 200/200 [00:18<00:00, 10.92it/s]
# Val Acc = 69.21% +- 1.32%
#
# Epoch 048/050 | Acc 90.581250  | Loss 0.245589: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 65.737500: 100%|██████████| 200/200 [00:18<00:00, 10.85it/s]
# Val Acc = 65.74% +- 1.28%
#
# Epoch 049/050 | Acc 90.225000  | Loss 0.259762: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 69.325000: 100%|██████████| 200/200 [00:18<00:00, 10.62it/s]
# Val Acc = 69.33% +- 1.34%
#
# Epoch 050/050 | Acc 90.962500  | Loss 0.234435: 100%|█| 200/200 [00:57<00:00,  3
# Validation    | Acc 68.562500: 100%|██████████| 200/200 [00:18<00:00, 10.87it/s]
# Val Acc = 68.56% +- 1.35%
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/CIFAR_FS/novel.json
# Test loader contains 200 episodes
# Test       | Acc 20.000000: 100%|█████████████| 200/200 [00:20<00:00,  9.86it/s]
# 200 Test Acc = 20.00% +- 0.00%

# %%
#!python train_test.py --method FSCT_cosine --dataset CUB --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 200 --test_iter 200

# %%
#!python train_test.py --method FSCT_cosine --dataset Omniglot --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 200 --test_iter 200

# %%
#!python train_test.py --method FSCT_cosine --dataset Yoga --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 10 --test_iter 0
