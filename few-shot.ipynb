# %%
# !git clone --single-branch --branch B https://github.com/VCoklat/Few-Shot-Cosine-Transformer.git
# !pip install -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt
# %cd /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/
# !source download_miniImagenet.sh
# %cd ../../../
# %cd /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/
# Out:
# Cloning into 'Few-Shot-Cosine-Transformer'...
# remote: Enumerating objects: 330454, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 330454 (delta 70), reused 51 (delta 48), pack-reused 330371 (from 2)
# Receiving objects: 100% (330454/330454), 2.41 GiB | 54.08 MiB/s, done.
# Resolving deltas: 100% (304/304), done.
# Updating files: 100% (296648/296648), done.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 3)) (0.20.1+cu121)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 6)) (3.12.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (3.7.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 10)) (11.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from -r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (0.19.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.11.0a2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (1.3.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (4.0.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2024.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 12)) (5.0.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->-r /kaggle/working/Few-Shot-Cosine-Transformer/requirements.txt (line 8)) (2024.2.0)
# /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet
# --2025-04-11 17:15:46--  https://raw.githubusercontent.com/twitter/meta-learning-lstm/master/data/miniImagenet/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1228815 (1.2M) [text/plain]
# Saving to: ‘train.csv.1’
#
# train.csv.1         100%[===================>]   1.17M  --.-KB/s    in 0.04s
#
# 2025-04-11 17:15:47 (29.9 MB/s) - ‘train.csv.1’ saved [1228815/1228815]
#
# --2025-04-11 17:15:47--  https://raw.githubusercontent.com/twitter/meta-learning-lstm/master/data/miniImagenet/val.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 307215 (300K) [text/plain]
# Saving to: ‘val.csv.1’
#
# val.csv.1           100%[===================>] 300.01K  --.-KB/s    in 0.02s
#
# 2025-04-11 17:15:47 (12.5 MB/s) - ‘val.csv.1’ saved [307215/307215]
#
# --2025-04-11 17:15:47--  https://raw.githubusercontent.com/twitter/meta-learning-lstm/master/data/miniImagenet/test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384015 (375K) [text/plain]
# Saving to: ‘test.csv.1’
#
# test.csv.1          100%[===================>] 375.01K  --.-KB/s    in 0.02s
#
# 2025-04-11 17:15:48 (16.6 MB/s) - ‘test.csv.1’ saved [384015/384015]
#
# /kaggle/working
# /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet

# %%
import numpy as np
from os import listdir
from os.path import isfile, isdir, join
import os
import json
import random
import re

cwd = os.getcwd()
data_path = '/kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/image/'
savedir = './'
dataset_list = ['base', 'val', 'novel']

cl = -1
folderlist = []  # to store label??

datasetmap = {'base': 'train', 'val': 'val', 'novel': 'test'}

filelists = {'base': {}, 'val': {}, 'novel': {}}
filelists_flat = {'base': [], 'val': [], 'novel': []}
labellists_flat = {'base': [], 'val': [], 'novel': []}

for dataset in dataset_list:
    with open(datasetmap[dataset] + ".csv", "r") as lines:
        for i, line in enumerate(lines):
            if i == 0:
                continue
            fid, _, label = re.split(',|\.', line)
            label = label.replace('\n', '')
            if not label in filelists[dataset]:
                folderlist.append(label)
                filelists[dataset][label] = []  # new label
                fnames = listdir(join(data_path, label))
            name = fid + '.jpg'
            fname = join(data_path, label, name)
            filelists[dataset][label].append(fname)

    for key, filelist in filelists[dataset].items():
        cl += 1
        random.shuffle(filelist)
        filelists_flat[dataset] += filelist
        labellists_flat[dataset] += np.repeat(cl, len(filelist)).tolist()

for dataset in dataset_list:
    fo = open(savedir + dataset + ".json", "w")
    fo.write('{"label_names": [')
    fo.writelines(['"%s",' % item for item in folderlist])
    fo.seek(0, os.SEEK_END)
    fo.seek(fo.tell()-1, os.SEEK_SET)
    fo.write('],')

    fo.write('"image_names": [')
    fo.writelines(['"%s",' % item for item in filelists_flat[dataset]])
    fo.seek(0, os.SEEK_END)
    fo.seek(fo.tell()-1, os.SEEK_SET)
    fo.write('],')

    fo.write('"image_labels": [')
    fo.writelines(['%d,' % item for item in labellists_flat[dataset]])
    fo.seek(0, os.SEEK_END)
    fo.seek(fo.tell()-1, os.SEEK_SET)
    fo.write(']}')

    fo.close()
    print("%s -OK" % dataset)
# Out:
# base -OK
# val -OK
# novel -OK

# %%
import numpy as np
from os import listdir
from os.path import isfile, isdir, join
import os
import json
import random
import re

cwd = os.getcwd()
data_path = '/kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/image/'
savedir = './'
dataset_list = ['base', 'val', 'novel']


cl = -1
folderlist = []

datasetmap = {'base': 'train', 'val': 'val', 'novel': 'test'}
filelists = {'base': {}, 'val': {}, 'novel': {}}
filelists_flat = {'base': [], 'val': [], 'novel': []}
labellists_flat = {'base': [], 'val': [], 'novel': []}

for dataset in dataset_list:
    with open(datasetmap[dataset] + ".csv", "r") as lines:
        for i, line in enumerate(lines):
            if i == 0:
                continue
            fid, _, label = re.split(',|\.', line)
            label = label.replace('\n', '')
            if not label in filelists[dataset]:
                folderlist.append(label)
                filelists[dataset][label] = []
                fnames = listdir(join(data_path, label))
            name = fid + '.jpg'
            fname = join(data_path, label, name)
            filelists[dataset][label].append(fname)

    for key, filelist in filelists[dataset].items():
        cl += 1
        random.shuffle(filelist)
        filelists_flat[dataset] += filelist
        labellists_flat[dataset] += np.repeat(cl, len(filelist)).tolist()

# cross setting use base/val/novel together
filelists_flat_all = filelists_flat['base'] + \
    filelists_flat['val'] + filelists_flat['novel']
labellists_flat_all = labellists_flat['base'] + \
    labellists_flat['val'] + labellists_flat['novel']
fo = open(savedir + "all.json", "w")
fo.write('{"label_names": [')
fo.writelines(['"%s",' % item for item in folderlist])
fo.seek(0, os.SEEK_END)
fo.seek(fo.tell()-1, os.SEEK_SET)
fo.write('],')

fo.write('"image_names": [')
fo.writelines(['"%s",' % item for item in filelists_flat_all])
fo.seek(0, os.SEEK_END)
fo.seek(fo.tell()-1, os.SEEK_SET)
fo.write('],')

fo.write('"image_labels": [')
fo.writelines(['%d,' % item for item in labellists_flat_all])
fo.seek(0, os.SEEK_END)
fo.seek(fo.tell()-1, os.SEEK_SET)
fo.write(']}')

fo.close()
print("all -OK")
# Out:
# all -OK

# %%
# %cd ../../
# Out:
# /kaggle/working/Few-Shot-Cosine-Transformer

# %%
# !python train_test.py --method FSCT_cosine --dataset miniImagenet --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 10 --test_iter 10
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'miniImagenet',
#     'datetime': '20250411@171602',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 10,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 10,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 22.250000  | Loss 1.677724: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 20.125000: 100%|████████████| 10/10 [00:04<00:00,  2.40it/s]
# Val Acc = 20.12% +- 1.85%
# best model! save...
#
# Epoch 002/050 | Acc 23.250000  | Loss 1.645892: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 18.750000: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 18.75% +- 2.47%
#
# Epoch 003/050 | Acc 19.625000  | Loss 1.620317: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.500000: 100%|████████████| 10/10 [00:04<00:00,  2.45it/s]
# Val Acc = 21.50% +- 3.02%
# best model! save...
#
# Epoch 004/050 | Acc 21.000000  | Loss 1.621714: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 19.250000: 100%|████████████| 10/10 [00:04<00:00,  2.43it/s]
# Val Acc = 19.25% +- 1.67%
#
# Epoch 005/050 | Acc 21.375000  | Loss 1.613256: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.625000: 100%|████████████| 10/10 [00:03<00:00,  2.51it/s]
# Val Acc = 20.62% +- 2.36%
#
# Epoch 006/050 | Acc 23.125000  | Loss 1.607731: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.375000: 100%|████████████| 10/10 [00:04<00:00,  2.39it/s]
# Val Acc = 20.38% +- 1.59%
#
# Epoch 007/050 | Acc 26.250000  | Loss 1.609970: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 23.000000: 100%|████████████| 10/10 [00:04<00:00,  2.45it/s]
# Val Acc = 23.00% +- 1.97%
# best model! save...
#
# Epoch 008/050 | Acc 24.625000  | Loss 1.606092: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.750000: 100%|████████████| 10/10 [00:04<00:00,  2.41it/s]
# Val Acc = 20.75% +- 1.67%
#
# Epoch 009/050 | Acc 21.625000  | Loss 1.604515: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 22.625000: 100%|████████████| 10/10 [00:04<00:00,  2.50it/s]
# Val Acc = 22.62% +- 4.02%
#
# Epoch 010/050 | Acc 23.750000  | Loss 1.616217: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 28.000000: 100%|████████████| 10/10 [00:04<00:00,  2.39it/s]
# Val Acc = 28.00% +- 3.10%
# best model! save...
#
# Epoch 011/050 | Acc 23.500000  | Loss 1.607295: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.625000: 100%|████████████| 10/10 [00:04<00:00,  2.39it/s]
# Val Acc = 21.62% +- 2.66%
#
# Epoch 012/050 | Acc 23.875000  | Loss 1.616468: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 24.250000: 100%|████████████| 10/10 [00:04<00:00,  2.47it/s]
# Val Acc = 24.25% +- 3.12%
#
# Epoch 013/050 | Acc 28.500000  | Loss 1.606839: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.625000: 100%|████████████| 10/10 [00:04<00:00,  2.34it/s]
# Val Acc = 21.62% +- 1.84%
#
# Epoch 014/050 | Acc 21.000000  | Loss 1.610772: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.875000: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 20.88% +- 2.50%
#
# Epoch 015/050 | Acc 21.500000  | Loss 1.610755: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.875000: 100%|████████████| 10/10 [00:04<00:00,  2.40it/s]
# Val Acc = 21.88% +- 1.87%
#
# Epoch 016/050 | Acc 21.000000  | Loss 1.611027: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.875000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 20.88% +- 1.39%
#
# Epoch 017/050 | Acc 21.250000  | Loss 1.608310: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.750000: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 21.75% +- 4.73%
#
# Epoch 018/050 | Acc 23.250000  | Loss 1.604345: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 19.375000: 100%|████████████| 10/10 [00:04<00:00,  2.38it/s]
# Val Acc = 19.38% +- 1.35%
#
# Epoch 019/050 | Acc 22.500000  | Loss 1.603002: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 23.125000: 100%|████████████| 10/10 [00:04<00:00,  2.38it/s]
# Val Acc = 23.12% +- 1.94%
#
# Epoch 020/050 | Acc 21.375000  | Loss 1.611634: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.750000: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 21.75% +- 1.39%
#
# Epoch 021/050 | Acc 19.750000  | Loss 1.610464: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 19.500000: 100%|████████████| 10/10 [00:04<00:00,  2.44it/s]
# Val Acc = 19.50% +- 0.79%
#
# Epoch 022/050 | Acc 21.625000  | Loss 1.604788: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 19.250000: 100%|████████████| 10/10 [00:04<00:00,  2.47it/s]
# Val Acc = 19.25% +- 2.30%
#
# Epoch 023/050 | Acc 22.375000  | Loss 1.606310: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.375000: 100%|████████████| 10/10 [00:04<00:00,  2.41it/s]
# Val Acc = 21.38% +- 2.39%
#
# Epoch 024/050 | Acc 21.375000  | Loss 1.607474: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 19.375000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 19.38% +- 2.92%
#
# Epoch 025/050 | Acc 22.000000  | Loss 1.605518: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.375000: 100%|████████████| 10/10 [00:04<00:00,  2.32it/s]
# Val Acc = 21.38% +- 2.72%
#
# Epoch 026/050 | Acc 22.375000  | Loss 1.611591: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.000000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 20.00% +- 2.47%
#
# Epoch 027/050 | Acc 23.250000  | Loss 1.605012: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.125000: 100%|████████████| 10/10 [00:04<00:00,  2.44it/s]
# Val Acc = 20.12% +- 0.73%
#
# Epoch 028/050 | Acc 20.250000  | Loss 1.612512: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 18.750000: 100%|████████████| 10/10 [00:04<00:00,  2.45it/s]
# Val Acc = 18.75% +- 1.51%
#
# Epoch 029/050 | Acc 20.750000  | Loss 1.607380: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.750000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 20.75% +- 2.30%
#
# Epoch 030/050 | Acc 21.625000  | Loss 1.603125: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 20.750000: 100%|████████████| 10/10 [00:04<00:00,  2.31it/s]
# Val Acc = 20.75% +- 2.22%
#
# Epoch 031/050 | Acc 21.750000  | Loss 1.602035: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.625000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 21.62% +- 1.90%
#
# Epoch 032/050 | Acc 23.375000  | Loss 1.592048: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 18.125000: 100%|████████████| 10/10 [00:04<00:00,  2.25it/s]
# Val Acc = 18.12% +- 1.26%
#
# Epoch 033/050 | Acc 20.875000  | Loss 1.612235: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.750000: 100%|████████████| 10/10 [00:04<00:00,  2.47it/s]
# Val Acc = 21.75% +- 1.77%
#
# Epoch 034/050 | Acc 21.750000  | Loss 1.604308: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.750000: 100%|████████████| 10/10 [00:04<00:00,  2.27it/s]
# Val Acc = 21.75% +- 2.06%
#
# Epoch 035/050 | Acc 23.375000  | Loss 1.598786: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 23.375000: 100%|████████████| 10/10 [00:03<00:00,  2.59it/s]
# Val Acc = 23.38% +- 2.48%
#
# Epoch 036/050 | Acc 25.125000  | Loss 1.569618: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 21.500000: 100%|████████████| 10/10 [00:04<00:00,  2.37it/s]
# Val Acc = 21.50% +- 2.34%
#
# Epoch 037/050 | Acc 22.125000  | Loss 1.597878: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 24.500000: 100%|████████████| 10/10 [00:04<00:00,  2.39it/s]
# Val Acc = 24.50% +- 3.20%
#
# Epoch 038/050 | Acc 26.375000  | Loss 1.577442: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 22.375000: 100%|████████████| 10/10 [00:04<00:00,  2.43it/s]
# Val Acc = 22.38% +- 3.11%
#
# Epoch 039/050 | Acc 25.000000  | Loss 1.602958: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 18.125000: 100%|████████████| 10/10 [00:04<00:00,  2.49it/s]
# Val Acc = 18.12% +- 2.64%
#
# Epoch 040/050 | Acc 23.750000  | Loss 1.606193: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 22.000000: 100%|████████████| 10/10 [00:04<00:00,  2.36it/s]
# Val Acc = 22.00% +- 2.28%
#
# Epoch 041/050 | Acc 24.000000  | Loss 1.598285: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 24.250000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 24.25% +- 2.62%
#
# Epoch 042/050 | Acc 25.875000  | Loss 1.586118: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 23.750000: 100%|████████████| 10/10 [00:04<00:00,  2.45it/s]
# Val Acc = 23.75% +- 2.25%
#
# Epoch 043/050 | Acc 26.625000  | Loss 1.573565: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 27.125000: 100%|████████████| 10/10 [00:04<00:00,  2.38it/s]
# Val Acc = 27.12% +- 2.84%
#
# Epoch 044/050 | Acc 29.375000  | Loss 1.536709: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 22.000000: 100%|████████████| 10/10 [00:04<00:00,  2.42it/s]
# Val Acc = 22.00% +- 1.97%
#
# Epoch 045/050 | Acc 29.500000  | Loss 1.531045: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 25.250000: 100%|████████████| 10/10 [00:03<00:00,  2.50it/s]
# Val Acc = 25.25% +- 1.86%
#
# Epoch 046/050 | Acc 30.250000  | Loss 1.537071: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 28.500000: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 28.50% +- 2.81%
# best model! save...
#
# Epoch 047/050 | Acc 27.375000  | Loss 1.587862: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 25.875000: 100%|████████████| 10/10 [00:04<00:00,  2.44it/s]
# Val Acc = 25.88% +- 4.22%
#
# Epoch 048/050 | Acc 25.625000  | Loss 1.553989: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 29.500000: 100%|████████████| 10/10 [00:04<00:00,  2.40it/s]
# Val Acc = 29.50% +- 2.55%
# best model! save...
#
# Epoch 049/050 | Acc 25.500000  | Loss 1.579582: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 29.750000: 100%|████████████| 10/10 [00:04<00:00,  2.49it/s]
# Val Acc = 29.75% +- 3.44%
# best model! save...
#
# Epoch 050/050 | Acc 31.750000  | Loss 1.533472: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 25.875000: 100%|████████████| 10/10 [00:04<00:00,  2.48it/s]
# Val Acc = 25.88% +- 3.31%
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/miniImagenet/novel.json
# Test loader contains 10 episodes
# Test       | Acc 20.000000: 100%|███████████████| 10/10 [00:04<00:00,  2.39it/s]
# 10 Test Acc = 20.00% +- 0.00%

# %%
# !python train_test.py --method FSCT_cosine --dataset CIFAR --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 10 --test_iter 10
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'CIFAR',
#     'datetime': '20250411@172923',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 10,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 10,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 23.875000  | Loss 1.619574: 100%|█| 10/10 [00:04<00:00,  2.3
# Validation    | Acc 20.000000: 100%|████████████| 10/10 [00:01<00:00,  6.15it/s]
# Val Acc = 20.00% +- 0.00%
# best model! save...
#
# Epoch 002/050 | Acc 28.000000  | Loss 1.599049: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 20.250000: 100%|████████████| 10/10 [00:01<00:00,  6.10it/s]
# Val Acc = 20.25% +- 2.29%
# best model! save...
#
# Epoch 003/050 | Acc 30.375000  | Loss 1.562293: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 30.750000: 100%|████████████| 10/10 [00:01<00:00,  6.07it/s]
# Val Acc = 30.75% +- 3.75%
# best model! save...
#
# Epoch 004/050 | Acc 29.500000  | Loss 1.616890: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 28.500000: 100%|████████████| 10/10 [00:01<00:00,  6.20it/s]
# Val Acc = 28.50% +- 2.98%
#
# Epoch 005/050 | Acc 28.500000  | Loss 1.586551: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 32.750000: 100%|████████████| 10/10 [00:01<00:00,  6.62it/s]
# Val Acc = 32.75% +- 4.35%
# best model! save...
#
# Epoch 006/050 | Acc 35.750000  | Loss 1.492235: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.625000: 100%|████████████| 10/10 [00:01<00:00,  6.06it/s]
# Val Acc = 28.62% +- 4.28%
#
# Epoch 007/050 | Acc 32.000000  | Loss 1.531392: 100%|█| 10/10 [00:03<00:00,  2.9
# Validation    | Acc 26.875000: 100%|████████████| 10/10 [00:01<00:00,  6.02it/s]
# Val Acc = 26.88% +- 3.88%
#
# Epoch 008/050 | Acc 33.625000  | Loss 1.542328: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 29.750000: 100%|████████████| 10/10 [00:01<00:00,  6.32it/s]
# Val Acc = 29.75% +- 4.98%
#
# Epoch 009/050 | Acc 35.125000  | Loss 1.472140: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 30.875000: 100%|████████████| 10/10 [00:01<00:00,  5.44it/s]
# Val Acc = 30.88% +- 5.14%
#
# Epoch 010/050 | Acc 33.500000  | Loss 1.535479: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.875000: 100%|████████████| 10/10 [00:01<00:00,  6.26it/s]
# Val Acc = 28.88% +- 2.26%
#
# Epoch 011/050 | Acc 38.750000  | Loss 1.440950: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 26.000000: 100%|████████████| 10/10 [00:01<00:00,  6.19it/s]
# Val Acc = 26.00% +- 4.57%
#
# Epoch 012/050 | Acc 29.500000  | Loss 1.595422: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.375000: 100%|████████████| 10/10 [00:01<00:00,  6.07it/s]
# Val Acc = 28.38% +- 3.47%
#
# Epoch 013/050 | Acc 28.500000  | Loss 1.572571: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 28.375000: 100%|████████████| 10/10 [00:01<00:00,  6.31it/s]
# Val Acc = 28.38% +- 1.59%
#
# Epoch 014/050 | Acc 34.250000  | Loss 1.529405: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 30.375000: 100%|████████████| 10/10 [00:01<00:00,  6.40it/s]
# Val Acc = 30.38% +- 4.20%
#
# Epoch 015/050 | Acc 31.500000  | Loss 1.520763: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 27.875000: 100%|████████████| 10/10 [00:01<00:00,  6.22it/s]
# Val Acc = 27.88% +- 3.57%
#
# Epoch 016/050 | Acc 38.000000  | Loss 1.447469: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 32.750000: 100%|████████████| 10/10 [00:01<00:00,  5.97it/s]
# Val Acc = 32.75% +- 4.27%
#
# Epoch 017/050 | Acc 40.625000  | Loss 1.398578: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 30.375000: 100%|████████████| 10/10 [00:01<00:00,  6.22it/s]
# Val Acc = 30.38% +- 3.67%
#
# Epoch 018/050 | Acc 39.375000  | Loss 1.420932: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 24.000000: 100%|████████████| 10/10 [00:01<00:00,  6.52it/s]
# Val Acc = 24.00% +- 3.99%
#
# Epoch 019/050 | Acc 35.125000  | Loss 1.488251: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 29.750000: 100%|████████████| 10/10 [00:01<00:00,  6.53it/s]
# Val Acc = 29.75% +- 3.76%
#
# Epoch 020/050 | Acc 35.000000  | Loss 1.471658: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 32.625000: 100%|████████████| 10/10 [00:01<00:00,  6.29it/s]
# Val Acc = 32.62% +- 2.95%
#
# Epoch 021/050 | Acc 32.375000  | Loss 1.490224: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 27.625000: 100%|████████████| 10/10 [00:01<00:00,  6.16it/s]
# Val Acc = 27.62% +- 3.40%
#
# Epoch 022/050 | Acc 35.875000  | Loss 1.466274: 100%|█| 10/10 [00:03<00:00,  2.5
# Validation    | Acc 26.500000: 100%|████████████| 10/10 [00:01<00:00,  6.03it/s]
# Val Acc = 26.50% +- 3.46%
#
# Epoch 023/050 | Acc 38.125000  | Loss 1.423098: 100%|█| 10/10 [00:03<00:00,  2.9
# Validation    | Acc 34.250000: 100%|████████████| 10/10 [00:01<00:00,  6.24it/s]
# Val Acc = 34.25% +- 6.45%
# best model! save...
#
# Epoch 024/050 | Acc 42.625000  | Loss 1.378241: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 33.625000: 100%|████████████| 10/10 [00:01<00:00,  6.17it/s]
# Val Acc = 33.62% +- 5.10%
#
# Epoch 025/050 | Acc 39.625000  | Loss 1.393027: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 32.375000: 100%|████████████| 10/10 [00:01<00:00,  6.01it/s]
# Val Acc = 32.38% +- 4.08%
#
# Epoch 026/050 | Acc 36.625000  | Loss 1.472678: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.625000: 100%|████████████| 10/10 [00:01<00:00,  6.34it/s]
# Val Acc = 28.62% +- 1.91%
#
# Epoch 027/050 | Acc 41.250000  | Loss 1.406369: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 31.000000: 100%|████████████| 10/10 [00:01<00:00,  6.01it/s]
# Val Acc = 31.00% +- 4.61%
#
# Epoch 028/050 | Acc 38.500000  | Loss 1.383108: 100%|█| 10/10 [00:03<00:00,  2.6
# Validation    | Acc 32.250000: 100%|████████████| 10/10 [00:01<00:00,  6.34it/s]
# Val Acc = 32.25% +- 4.27%
#
# Epoch 029/050 | Acc 42.625000  | Loss 1.385632: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 33.875000: 100%|████████████| 10/10 [00:01<00:00,  6.06it/s]
# Val Acc = 33.88% +- 5.23%
#
# Epoch 030/050 | Acc 44.125000  | Loss 1.401455: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 33.875000: 100%|████████████| 10/10 [00:01<00:00,  6.01it/s]
# Val Acc = 33.88% +- 4.42%
#
# Epoch 031/050 | Acc 37.250000  | Loss 1.456376: 100%|█| 10/10 [00:03<00:00,  2.9
# Validation    | Acc 39.000000: 100%|████████████| 10/10 [00:01<00:00,  5.97it/s]
# Val Acc = 39.00% +- 5.26%
# best model! save...
#
# Epoch 032/050 | Acc 41.250000  | Loss 1.385120: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 33.500000: 100%|████████████| 10/10 [00:01<00:00,  6.26it/s]
# Val Acc = 33.50% +- 5.23%
#
# Epoch 033/050 | Acc 43.000000  | Loss 1.323697: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 36.000000: 100%|████████████| 10/10 [00:01<00:00,  6.36it/s]
# Val Acc = 36.00% +- 2.83%
#
# Epoch 034/050 | Acc 43.750000  | Loss 1.350477: 100%|█| 10/10 [00:03<00:00,  2.6
# Validation    | Acc 33.750000: 100%|████████████| 10/10 [00:01<00:00,  6.28it/s]
# Val Acc = 33.75% +- 3.19%
#
# Epoch 035/050 | Acc 42.750000  | Loss 1.366171: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 31.500000: 100%|████████████| 10/10 [00:01<00:00,  6.39it/s]
# Val Acc = 31.50% +- 3.36%
#
# Epoch 036/050 | Acc 38.500000  | Loss 1.436966: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 29.250000: 100%|████████████| 10/10 [00:01<00:00,  6.61it/s]
# Val Acc = 29.25% +- 4.32%
#
# Epoch 037/050 | Acc 33.750000  | Loss 1.467986: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.875000: 100%|████████████| 10/10 [00:01<00:00,  6.28it/s]
# Val Acc = 28.88% +- 5.49%
#
# Epoch 038/050 | Acc 36.625000  | Loss 1.384297: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.375000: 100%|████████████| 10/10 [00:01<00:00,  6.32it/s]
# Val Acc = 28.38% +- 4.44%
#
# Epoch 039/050 | Acc 38.875000  | Loss 1.446951: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 26.500000: 100%|████████████| 10/10 [00:01<00:00,  6.56it/s]
# Val Acc = 26.50% +- 3.37%
#
# Epoch 040/050 | Acc 41.125000  | Loss 1.381457: 100%|█| 10/10 [00:03<00:00,  2.7
# Validation    | Acc 35.750000: 100%|████████████| 10/10 [00:01<00:00,  6.16it/s]
# Val Acc = 35.75% +- 3.80%
#
# Epoch 041/050 | Acc 38.250000  | Loss 1.365563: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 35.750000: 100%|████████████| 10/10 [00:01<00:00,  6.41it/s]
# Val Acc = 35.75% +- 4.27%
#
# Epoch 042/050 | Acc 37.250000  | Loss 1.440410: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 31.375000: 100%|████████████| 10/10 [00:01<00:00,  6.17it/s]
# Val Acc = 31.38% +- 3.52%
#
# Epoch 043/050 | Acc 37.375000  | Loss 1.390446: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 34.625000: 100%|████████████| 10/10 [00:01<00:00,  6.25it/s]
# Val Acc = 34.62% +- 3.78%
#
# Epoch 044/050 | Acc 33.000000  | Loss 1.483507: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 35.750000: 100%|████████████| 10/10 [00:01<00:00,  6.27it/s]
# Val Acc = 35.75% +- 4.73%
#
# Epoch 045/050 | Acc 38.000000  | Loss 1.437768: 100%|█| 10/10 [00:03<00:00,  2.6
# Validation    | Acc 36.250000: 100%|████████████| 10/10 [00:01<00:00,  6.37it/s]
# Val Acc = 36.25% +- 2.86%
#
# Epoch 046/050 | Acc 36.375000  | Loss 1.469875: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 28.750000: 100%|████████████| 10/10 [00:01<00:00,  5.85it/s]
# Val Acc = 28.75% +- 4.85%
#
# Epoch 047/050 | Acc 44.000000  | Loss 1.348288: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 30.375000: 100%|████████████| 10/10 [00:01<00:00,  6.45it/s]
# Val Acc = 30.38% +- 2.94%
#
# Epoch 048/050 | Acc 36.750000  | Loss 1.490726: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 34.500000: 100%|████████████| 10/10 [00:01<00:00,  6.11it/s]
# Val Acc = 34.50% +- 4.51%
#
# Epoch 049/050 | Acc 40.000000  | Loss 1.426215: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 33.125000: 100%|████████████| 10/10 [00:01<00:00,  6.17it/s]
# Val Acc = 33.12% +- 4.00%
#
# Epoch 050/050 | Acc 41.000000  | Loss 1.349592: 100%|█| 10/10 [00:03<00:00,  2.8
# Validation    | Acc 34.500000: 100%|████████████| 10/10 [00:01<00:00,  5.91it/s]
# Val Acc = 34.50% +- 5.31%
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/CIFAR_FS/novel.json
# Test loader contains 10 episodes
# Test       | Acc 20.000000: 100%|███████████████| 10/10 [00:01<00:00,  5.53it/s]
# 10 Test Acc = 20.00% +- 0.00%

# %%
# !python train_test.py --method FSCT_cosine --dataset CUB --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 10 --test_iter 10
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'CUB',
#     'datetime': '20250411@173358',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 10,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 10,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 20.625000  | Loss 1.663740: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 19.750000: 100%|████████████| 10/10 [00:04<00:00,  2.03it/s]
# Val Acc = 19.75% +- 0.76%
# best model! save...
#
# Epoch 002/050 | Acc 20.750000  | Loss 1.609300: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 19.625000: 100%|████████████| 10/10 [00:04<00:00,  2.04it/s]
# Val Acc = 19.62% +- 1.55%
#
# Epoch 003/050 | Acc 20.875000  | Loss 1.609288: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 22.125000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 22.12% +- 1.70%
# best model! save...
#
# Epoch 004/050 | Acc 20.875000  | Loss 1.607725: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 22.375000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 22.38% +- 2.34%
# best model! save...
#
# Epoch 005/050 | Acc 20.375000  | Loss 1.614315: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 22.750000: 100%|████████████| 10/10 [00:05<00:00,  1.93it/s]
# Val Acc = 22.75% +- 3.13%
# best model! save...
#
# Epoch 006/050 | Acc 22.750000  | Loss 1.609468: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 21.750000: 100%|████████████| 10/10 [00:05<00:00,  1.97it/s]
# Val Acc = 21.75% +- 2.03%
#
# Epoch 007/050 | Acc 22.875000  | Loss 1.654110: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 31.500000: 100%|████████████| 10/10 [00:05<00:00,  1.84it/s]
# Val Acc = 31.50% +- 3.11%
# best model! save...
#
# Epoch 008/050 | Acc 26.125000  | Loss 1.605533: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 29.500000: 100%|████████████| 10/10 [00:05<00:00,  1.93it/s]
# Val Acc = 29.50% +- 2.60%
#
# Epoch 009/050 | Acc 30.375000  | Loss 1.548554: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 33.875000: 100%|████████████| 10/10 [00:05<00:00,  1.95it/s]
# Val Acc = 33.88% +- 4.67%
# best model! save...
#
# Epoch 010/050 | Acc 32.500000  | Loss 1.498265: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 29.375000: 100%|████████████| 10/10 [00:04<00:00,  2.01it/s]
# Val Acc = 29.38% +- 4.28%
#
# Epoch 011/050 | Acc 32.500000  | Loss 1.491590: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 32.000000: 100%|████████████| 10/10 [00:04<00:00,  2.06it/s]
# Val Acc = 32.00% +- 5.01%
#
# Epoch 012/050 | Acc 36.000000  | Loss 1.516124: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 33.000000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 33.00% +- 3.81%
#
# Epoch 013/050 | Acc 29.250000  | Loss 1.536059: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 34.000000: 100%|████████████| 10/10 [00:05<00:00,  1.89it/s]
# Val Acc = 34.00% +- 3.93%
# best model! save...
#
# Epoch 014/050 | Acc 40.625000  | Loss 1.415232: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 28.500000: 100%|████████████| 10/10 [00:05<00:00,  1.94it/s]
# Val Acc = 28.50% +- 3.15%
#
# Epoch 015/050 | Acc 40.125000  | Loss 1.418698: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 42.625000: 100%|████████████| 10/10 [00:05<00:00,  1.93it/s]
# Val Acc = 42.62% +- 4.84%
# best model! save...
#
# Epoch 016/050 | Acc 38.750000  | Loss 1.412896: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 35.625000: 100%|████████████| 10/10 [00:05<00:00,  1.97it/s]
# Val Acc = 35.62% +- 4.33%
#
# Epoch 017/050 | Acc 38.375000  | Loss 1.418181: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 34.625000: 100%|████████████| 10/10 [00:05<00:00,  1.95it/s]
# Val Acc = 34.62% +- 3.55%
#
# Epoch 018/050 | Acc 30.750000  | Loss 1.545311: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 34.125000: 100%|████████████| 10/10 [00:05<00:00,  1.92it/s]
# Val Acc = 34.12% +- 5.40%
#
# Epoch 019/050 | Acc 36.000000  | Loss 1.399821: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 39.000000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 39.00% +- 4.31%
#
# Epoch 020/050 | Acc 38.500000  | Loss 1.462986: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 38.625000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 38.62% +- 5.40%
#
# Epoch 021/050 | Acc 34.125000  | Loss 1.463620: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 39.500000: 100%|████████████| 10/10 [00:05<00:00,  1.98it/s]
# Val Acc = 39.50% +- 4.06%
#
# Epoch 022/050 | Acc 48.500000  | Loss 1.283180: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 43.625000: 100%|████████████| 10/10 [00:05<00:00,  1.90it/s]
# Val Acc = 43.62% +- 5.92%
# best model! save...
#
# Epoch 023/050 | Acc 47.875000  | Loss 1.239483: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 38.250000: 100%|████████████| 10/10 [00:05<00:00,  1.91it/s]
# Val Acc = 38.25% +- 5.06%
#
# Epoch 024/050 | Acc 43.375000  | Loss 1.242220: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 38.250000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 38.25% +- 5.09%
#
# Epoch 025/050 | Acc 42.375000  | Loss 1.328170: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 40.500000: 100%|████████████| 10/10 [00:05<00:00,  1.91it/s]
# Val Acc = 40.50% +- 4.78%
#
# Epoch 026/050 | Acc 43.000000  | Loss 1.319762: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 37.750000: 100%|████████████| 10/10 [00:05<00:00,  1.94it/s]
# Val Acc = 37.75% +- 5.88%
#
# Epoch 027/050 | Acc 41.500000  | Loss 1.345977: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 42.250000: 100%|████████████| 10/10 [00:05<00:00,  1.98it/s]
# Val Acc = 42.25% +- 4.35%
#
# Epoch 028/050 | Acc 45.125000  | Loss 1.306788: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.625000: 100%|████████████| 10/10 [00:05<00:00,  1.92it/s]
# Val Acc = 46.62% +- 4.50%
# best model! save...
#
# Epoch 029/050 | Acc 47.750000  | Loss 1.214016: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 37.875000: 100%|████████████| 10/10 [00:05<00:00,  1.95it/s]
# Val Acc = 37.88% +- 4.34%
#
# Epoch 030/050 | Acc 43.875000  | Loss 1.240321: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 37.750000: 100%|████████████| 10/10 [00:05<00:00,  1.86it/s]
# Val Acc = 37.75% +- 5.99%
#
# Epoch 031/050 | Acc 46.375000  | Loss 1.255044: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.500000: 100%|████████████| 10/10 [00:05<00:00,  1.93it/s]
# Val Acc = 46.50% +- 5.89%
#
# Epoch 032/050 | Acc 45.375000  | Loss 1.258028: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 43.625000: 100%|████████████| 10/10 [00:05<00:00,  1.73it/s]
# Val Acc = 43.62% +- 7.23%
#
# Epoch 033/050 | Acc 49.250000  | Loss 1.200560: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 45.000000: 100%|████████████| 10/10 [00:05<00:00,  1.98it/s]
# Val Acc = 45.00% +- 4.94%
#
# Epoch 034/050 | Acc 50.125000  | Loss 1.197765: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.125000: 100%|████████████| 10/10 [00:04<00:00,  2.01it/s]
# Val Acc = 46.12% +- 4.59%
#
# Epoch 035/050 | Acc 45.625000  | Loss 1.267392: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 42.750000: 100%|████████████| 10/10 [00:05<00:00,  1.97it/s]
# Val Acc = 42.75% +- 4.14%
#
# Epoch 036/050 | Acc 53.500000  | Loss 1.086138: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 44.125000: 100%|████████████| 10/10 [00:05<00:00,  1.90it/s]
# Val Acc = 44.12% +- 5.71%
#
# Epoch 037/050 | Acc 49.125000  | Loss 1.192861: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 39.000000: 100%|████████████| 10/10 [00:05<00:00,  1.97it/s]
# Val Acc = 39.00% +- 6.85%
#
# Epoch 038/050 | Acc 48.000000  | Loss 1.326437: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.625000: 100%|████████████| 10/10 [00:05<00:00,  1.95it/s]
# Val Acc = 46.62% +- 3.94%
#
# Epoch 039/050 | Acc 55.750000  | Loss 1.071316: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.125000: 100%|████████████| 10/10 [00:05<00:00,  1.96it/s]
# Val Acc = 46.12% +- 6.03%
#
# Epoch 040/050 | Acc 48.000000  | Loss 1.293365: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 49.875000: 100%|████████████| 10/10 [00:05<00:00,  1.95it/s]
# Val Acc = 49.88% +- 6.23%
# best model! save...
#
# Epoch 041/050 | Acc 49.500000  | Loss 1.264205: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.250000: 100%|████████████| 10/10 [00:05<00:00,  1.83it/s]
# Val Acc = 46.25% +- 4.04%
#
# Epoch 042/050 | Acc 55.750000  | Loss 1.172830: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 39.250000: 100%|████████████| 10/10 [00:04<00:00,  2.05it/s]
# Val Acc = 39.25% +- 6.49%
#
# Epoch 043/050 | Acc 53.750000  | Loss 1.101520: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 55.250000: 100%|████████████| 10/10 [00:04<00:00,  2.02it/s]
# Val Acc = 55.25% +- 6.65%
# best model! save...
#
# Epoch 044/050 | Acc 55.500000  | Loss 1.049287: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 48.875000: 100%|████████████| 10/10 [00:05<00:00,  1.94it/s]
# Val Acc = 48.88% +- 7.54%
#
# Epoch 045/050 | Acc 49.375000  | Loss 1.180091: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 53.000000: 100%|████████████| 10/10 [00:05<00:00,  1.94it/s]
# Val Acc = 53.00% +- 6.87%
#
# Epoch 046/050 | Acc 49.750000  | Loss 1.190511: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 46.625000: 100%|████████████| 10/10 [00:05<00:00,  2.00it/s]
# Val Acc = 46.62% +- 7.94%
#
# Epoch 047/050 | Acc 61.250000  | Loss 0.951257: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 58.500000: 100%|████████████| 10/10 [00:05<00:00,  1.99it/s]
# Val Acc = 58.50% +- 4.67%
# best model! save...
#
# Epoch 048/050 | Acc 52.250000  | Loss 1.147167: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 49.750000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 49.75% +- 3.44%
#
# Epoch 049/050 | Acc 53.500000  | Loss 1.062809: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 53.875000: 100%|████████████| 10/10 [00:04<00:00,  2.01it/s]
# Val Acc = 53.88% +- 6.09%
#
# Epoch 050/050 | Acc 52.500000  | Loss 1.138262: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 57.125000: 100%|████████████| 10/10 [00:05<00:00,  1.91it/s]
# Val Acc = 57.12% +- 9.72%
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/CUB/novel.json
# Test loader contains 10 episodes
# Test       | Acc 20.000000: 100%|███████████████| 10/10 [00:05<00:00,  1.89it/s]
# 10 Test Acc = 20.00% +- 0.00%

# %%
# !python train_test.py --method FSCT_cosine --dataset Omniglot --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 10 --test_iter 10
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'Omniglot',
#     'datetime': '20250411@174906',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 10,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 10,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 39.600000  | Loss 1.452485: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 20.133333: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 20.13% +- 1.75%
# best model! save...
#
# Epoch 002/050 | Acc 70.666667  | Loss 0.976776: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 55.466667: 100%|████████████| 10/10 [00:03<00:00,  2.51it/s]
# Val Acc = 55.47% +- 8.81%
# best model! save...
#
# Epoch 003/050 | Acc 83.200000  | Loss 0.663564: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 41.066667: 100%|████████████| 10/10 [00:04<00:00,  2.45it/s]
# Val Acc = 41.07% +- 6.35%
#
# Epoch 004/050 | Acc 86.666667  | Loss 0.501637: 100%|█| 10/10 [00:10<00:00,  1.1
# Validation    | Acc 83.600000: 100%|████████████| 10/10 [00:03<00:00,  2.53it/s]
# Val Acc = 83.60% +- 5.12%
# best model! save...
#
# Epoch 005/050 | Acc 87.200000  | Loss 0.409736: 100%|█| 10/10 [00:10<00:00,  1.1
# Validation    | Acc 84.666667: 100%|████████████| 10/10 [00:03<00:00,  2.55it/s]
# Val Acc = 84.67% +- 3.27%
# best model! save...
#
# Epoch 006/050 | Acc 88.266667  | Loss 0.345472: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 80.666667: 100%|████████████| 10/10 [00:04<00:00,  2.49it/s]
# Val Acc = 80.67% +- 7.35%
#
# Epoch 007/050 | Acc 90.000000  | Loss 0.344961: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 82.800000: 100%|████████████| 10/10 [00:04<00:00,  2.37it/s]
# Val Acc = 82.80% +- 4.30%
#
# Epoch 008/050 | Acc 91.866667  | Loss 0.250269: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 87.333333: 100%|████████████| 10/10 [00:04<00:00,  2.37it/s]
# Val Acc = 87.33% +- 3.61%
# best model! save...
#
# Epoch 009/050 | Acc 92.133333  | Loss 0.260581: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 90.400000: 100%|████████████| 10/10 [00:03<00:00,  2.51it/s]
# Val Acc = 90.40% +- 4.24%
# best model! save...
#
# Epoch 010/050 | Acc 92.266667  | Loss 0.225879: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 87.466667: 100%|████████████| 10/10 [00:03<00:00,  2.57it/s]
# Val Acc = 87.47% +- 4.09%
#
# Epoch 011/050 | Acc 91.200000  | Loss 0.276519: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 91.600000: 100%|████████████| 10/10 [00:04<00:00,  2.37it/s]
# Val Acc = 91.60% +- 2.45%
# best model! save...
#
# Epoch 012/050 | Acc 93.466667  | Loss 0.212911: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 89.733333: 100%|████████████| 10/10 [00:03<00:00,  2.55it/s]
# Val Acc = 89.73% +- 2.16%
#
# Epoch 013/050 | Acc 94.533333  | Loss 0.188650: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 86.266667: 100%|████████████| 10/10 [00:04<00:00,  2.22it/s]
# Val Acc = 86.27% +- 3.70%
#
# Epoch 014/050 | Acc 91.333333  | Loss 0.277966: 100%|█| 10/10 [00:10<00:00,  1.0
# Validation    | Acc 91.600000: 100%|████████████| 10/10 [00:03<00:00,  2.53it/s]
# Val Acc = 91.60% +- 3.14%
#
# Epoch 015/050 | Acc 95.733333  | Loss 0.146289: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 91.600000: 100%|████████████| 10/10 [00:03<00:00,  2.62it/s]
# Val Acc = 91.60% +- 3.86%
#
# Epoch 016/050 | Acc 95.066667  | Loss 0.185068: 100%|█| 10/10 [00:10<00:00,  1.1
# Validation    | Acc 94.933333: 100%|████████████| 10/10 [00:03<00:00,  2.51it/s]
# Val Acc = 94.93% +- 1.98%
# best model! save...
#
# Epoch 017/050 | Acc 93.200000  | Loss 0.199751: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 92.666667: 100%|████████████| 10/10 [00:03<00:00,  2.56it/s]
# Val Acc = 92.67% +- 3.41%
#
# Epoch 018/050 | Acc 92.133333  | Loss 0.251085: 100%|█| 10/10 [00:10<00:00,  1.0
# Validation    | Acc 92.133333: 100%|████████████| 10/10 [00:04<00:00,  2.43it/s]
# Val Acc = 92.13% +- 3.21%
#
# Epoch 019/050 | Acc 96.000000  | Loss 0.142335: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 92.400000: 100%|████████████| 10/10 [00:03<00:00,  2.52it/s]
# Val Acc = 92.40% +- 3.03%
#
# Epoch 020/050 | Acc 94.133333  | Loss 0.161785: 100%|█| 10/10 [00:10<00:00,  1.0
# Validation    | Acc 91.600000: 100%|████████████| 10/10 [00:03<00:00,  2.54it/s]
# Val Acc = 91.60% +- 2.84%
#
# Epoch 021/050 | Acc 94.933333  | Loss 0.153773: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 92.800000: 100%|████████████| 10/10 [00:03<00:00,  2.53it/s]
# Val Acc = 92.80% +- 3.16%
#
# Epoch 022/050 | Acc 94.266667  | Loss 0.174719: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 95.066667: 100%|████████████| 10/10 [00:03<00:00,  2.55it/s]
# Val Acc = 95.07% +- 4.36%
# best model! save...
#
# Epoch 023/050 | Acc 98.400000  | Loss 0.097160: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 93.600000: 100%|████████████| 10/10 [00:04<00:00,  2.37it/s]
# Val Acc = 93.60% +- 3.73%
#
# Epoch 024/050 | Acc 96.933333  | Loss 0.091807: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 95.200000: 100%|████████████| 10/10 [00:03<00:00,  2.54it/s]
# Val Acc = 95.20% +- 1.49%
# best model! save...
#
# Epoch 025/050 | Acc 97.200000  | Loss 0.102360: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 94.533333: 100%|████████████| 10/10 [00:03<00:00,  2.52it/s]
# Val Acc = 94.53% +- 2.23%
#
# Epoch 026/050 | Acc 96.266667  | Loss 0.099831: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 93.066667: 100%|████████████| 10/10 [00:04<00:00,  2.47it/s]
# Val Acc = 93.07% +- 3.50%
#
# Epoch 027/050 | Acc 97.866667  | Loss 0.068853: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 92.800000: 100%|████████████| 10/10 [00:04<00:00,  2.49it/s]
# Val Acc = 92.80% +- 2.59%
#
# Epoch 028/050 | Acc 95.866667  | Loss 0.148026: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 94.133333: 100%|████████████| 10/10 [00:03<00:00,  2.59it/s]
# Val Acc = 94.13% +- 1.96%
#
# Epoch 029/050 | Acc 97.466667  | Loss 0.095073: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.266667: 100%|████████████| 10/10 [00:03<00:00,  2.61it/s]
# Val Acc = 96.27% +- 1.98%
# best model! save...
#
# Epoch 030/050 | Acc 97.600000  | Loss 0.077041: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.133333: 100%|████████████| 10/10 [00:04<00:00,  2.48it/s]
# Val Acc = 96.13% +- 1.50%
#
# Epoch 031/050 | Acc 97.600000  | Loss 0.084482: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.933333: 100%|████████████| 10/10 [00:03<00:00,  2.57it/s]
# Val Acc = 96.93% +- 1.81%
# best model! save...
#
# Epoch 032/050 | Acc 96.533333  | Loss 0.133174: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 95.600000: 100%|████████████| 10/10 [00:03<00:00,  2.57it/s]
# Val Acc = 95.60% +- 2.59%
#
# Epoch 033/050 | Acc 98.000000  | Loss 0.087260: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 95.333333: 100%|████████████| 10/10 [00:03<00:00,  2.52it/s]
# Val Acc = 95.33% +- 2.10%
#
# Epoch 034/050 | Acc 95.866667  | Loss 0.110882: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.933333: 100%|████████████| 10/10 [00:03<00:00,  2.62it/s]
# Val Acc = 96.93% +- 1.57%
#
# Epoch 035/050 | Acc 96.666667  | Loss 0.083627: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.400000: 100%|████████████| 10/10 [00:03<00:00,  2.67it/s]
# Val Acc = 96.40% +- 1.81%
#
# Epoch 036/050 | Acc 95.733333  | Loss 0.116080: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 97.066667: 100%|████████████| 10/10 [00:03<00:00,  2.58it/s]
# Val Acc = 97.07% +- 1.56%
# best model! save...
#
# Epoch 037/050 | Acc 97.200000  | Loss 0.081012: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 95.333333: 100%|████████████| 10/10 [00:04<00:00,  2.37it/s]
# Val Acc = 95.33% +- 1.74%
#
# Epoch 038/050 | Acc 95.866667  | Loss 0.133151: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.266667: 100%|████████████| 10/10 [00:03<00:00,  2.52it/s]
# Val Acc = 96.27% +- 1.95%
#
# Epoch 039/050 | Acc 97.600000  | Loss 0.077567: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 97.466667: 100%|████████████| 10/10 [00:03<00:00,  2.54it/s]
# Val Acc = 97.47% +- 1.40%
# best model! save...
#
# Epoch 040/050 | Acc 96.666667  | Loss 0.093389: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.133333: 100%|████████████| 10/10 [00:04<00:00,  2.48it/s]
# Val Acc = 96.13% +- 1.36%
#
# Epoch 041/050 | Acc 97.466667  | Loss 0.076739: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 97.200000: 100%|████████████| 10/10 [00:03<00:00,  2.53it/s]
# Val Acc = 97.20% +- 1.30%
#
# Epoch 042/050 | Acc 98.800000  | Loss 0.058933: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.533333: 100%|████████████| 10/10 [00:03<00:00,  2.63it/s]
# Val Acc = 96.53% +- 1.34%
#
# Epoch 043/050 | Acc 98.133333  | Loss 0.054153: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 98.133333: 100%|████████████| 10/10 [00:03<00:00,  2.63it/s]
# Val Acc = 98.13% +- 0.92%
# best model! save...
#
# Epoch 044/050 | Acc 98.533333  | Loss 0.059953: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 97.066667: 100%|████████████| 10/10 [00:04<00:00,  2.47it/s]
# Val Acc = 97.07% +- 1.88%
#
# Epoch 045/050 | Acc 95.600000  | Loss 0.144082: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 94.933333: 100%|████████████| 10/10 [00:03<00:00,  2.53it/s]
# Val Acc = 94.93% +- 3.07%
#
# Epoch 046/050 | Acc 97.200000  | Loss 0.093813: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.133333: 100%|████████████| 10/10 [00:04<00:00,  2.33it/s]
# Val Acc = 96.13% +- 1.40%
#
# Epoch 047/050 | Acc 95.200000  | Loss 0.173016: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 97.600000: 100%|████████████| 10/10 [00:03<00:00,  2.58it/s]
# Val Acc = 97.60% +- 1.60%
#
# Epoch 048/050 | Acc 97.200000  | Loss 0.096037: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 96.533333: 100%|████████████| 10/10 [00:04<00:00,  2.41it/s]
# Val Acc = 96.53% +- 2.10%
#
# Epoch 049/050 | Acc 99.333333  | Loss 0.024110: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 97.733333: 100%|████████████| 10/10 [00:03<00:00,  2.52it/s]
# Val Acc = 97.73% +- 1.43%
#
# Epoch 050/050 | Acc 98.000000  | Loss 0.074970: 100%|█| 10/10 [00:11<00:00,  1.1
# Validation    | Acc 98.000000: 100%|████████████| 10/10 [00:04<00:00,  2.46it/s]
# Val Acc = 98.00% +- 1.12%
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/Omniglot/novel.json
# Test loader contains 10 episodes
# Test       | Acc 20.000000: 100%|███████████████| 10/10 [00:04<00:00,  2.20it/s]
# 10 Test Acc = 20.00% +- 0.00%

# %%
# !python train_test.py --method FSCT_cosine --dataset Yoga --backbone ResNet34 --FETI 1 --n_way 5 --k_shot 5 --train_aug 0 --n_episode 10 --test_iter 0
# Out:
# {   'FETI': 1,
#     'backbone': 'ResNet34',
#     'dataset': 'Yoga',
#     'datetime': '20250411@180210',
#     'k_shot': 5,
#     'learning_rate': 0.001,
#     'method': 'FSCT_cosine',
#     'momentum': 0.9,
#     'n_episode': 10,
#     'n_query': 16,
#     'n_way': 5,
#     'num_epoch': 50,
#     'optimization': 'AdamW',
#     'save_freq': 50,
#     'save_iter': -1,
#     'split': 'novel',
#     'test_iter': 0,
#     'train_aug': 0,
#     'wandb': 0,
#     'weight_decay': 1e-05}
#
# ===================================
# Train phase:
# Epoch 001/050 | Acc 28.500000  | Loss 1.642717: 100%|█| 10/10 [00:14<00:00,  1.4
# Validation    | Acc 24.375000: 100%|████████████| 10/10 [00:05<00:00,  1.68it/s]
# Val Acc = 24.38% +- 3.14%
# best model! save...
#
# Epoch 002/050 | Acc 26.500000  | Loss 1.598248: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 21.625000: 100%|████████████| 10/10 [00:06<00:00,  1.66it/s]
# Val Acc = 21.62% +- 2.02%
#
# Epoch 003/050 | Acc 25.000000  | Loss 1.614797: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 20.000000: 100%|████████████| 10/10 [00:06<00:00,  1.63it/s]
# Val Acc = 20.00% +- 0.35%
#
# Epoch 004/050 | Acc 23.000000  | Loss 1.609369: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 19.250000: 100%|████████████| 10/10 [00:05<00:00,  1.71it/s]
# Val Acc = 19.25% +- 1.26%
#
# Epoch 005/050 | Acc 24.875000  | Loss 1.609235: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 23.000000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 23.00% +- 3.36%
#
# Epoch 006/050 | Acc 23.125000  | Loss 1.605620: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 25.500000: 100%|████████████| 10/10 [00:05<00:00,  1.68it/s]
# Val Acc = 25.50% +- 3.04%
# best model! save...
#
# Epoch 007/050 | Acc 28.000000  | Loss 1.591716: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 28.625000: 100%|████████████| 10/10 [00:05<00:00,  1.74it/s]
# Val Acc = 28.62% +- 2.82%
# best model! save...
#
# Epoch 008/050 | Acc 26.750000  | Loss 1.583515: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 25.125000: 100%|████████████| 10/10 [00:05<00:00,  1.80it/s]
# Val Acc = 25.12% +- 4.25%
#
# Epoch 009/050 | Acc 28.375000  | Loss 1.605348: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 22.250000: 100%|████████████| 10/10 [00:05<00:00,  1.85it/s]
# Val Acc = 22.25% +- 1.98%
#
# Epoch 010/050 | Acc 28.500000  | Loss 1.579510: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 25.750000: 100%|████████████| 10/10 [00:05<00:00,  1.74it/s]
# Val Acc = 25.75% +- 2.11%
#
# Epoch 011/050 | Acc 34.500000  | Loss 1.513613: 100%|█| 10/10 [00:12<00:00,  1.3
# Validation    | Acc 32.000000: 100%|████████████| 10/10 [00:05<00:00,  1.80it/s]
# Val Acc = 32.00% +- 2.60%
# best model! save...
#
# Epoch 012/050 | Acc 37.000000  | Loss 1.536585: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 31.625000: 100%|████████████| 10/10 [00:05<00:00,  1.75it/s]
# Val Acc = 31.62% +- 4.93%
#
# Epoch 013/050 | Acc 43.500000  | Loss 1.490322: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 34.250000: 100%|████████████| 10/10 [00:05<00:00,  1.75it/s]
# Val Acc = 34.25% +- 3.65%
# best model! save...
#
# Epoch 014/050 | Acc 38.125000  | Loss 1.406600: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 33.875000: 100%|████████████| 10/10 [00:05<00:00,  1.72it/s]
# Val Acc = 33.88% +- 4.22%
#
# Epoch 015/050 | Acc 45.125000  | Loss 1.291994: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 42.500000: 100%|████████████| 10/10 [00:05<00:00,  1.76it/s]
# Val Acc = 42.50% +- 5.06%
# best model! save...
#
# Epoch 016/050 | Acc 50.250000  | Loss 1.218377: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 45.000000: 100%|████████████| 10/10 [00:06<00:00,  1.61it/s]
# Val Acc = 45.00% +- 4.04%
# best model! save...
#
# Epoch 017/050 | Acc 51.000000  | Loss 1.197446: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 42.250000: 100%|████████████| 10/10 [00:05<00:00,  1.69it/s]
# Val Acc = 42.25% +- 4.10%
#
# Epoch 018/050 | Acc 56.250000  | Loss 1.115757: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 38.125000: 100%|████████████| 10/10 [00:05<00:00,  1.83it/s]
# Val Acc = 38.12% +- 3.40%
#
# Epoch 019/050 | Acc 59.125000  | Loss 1.095303: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 39.125000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 39.12% +- 3.76%
#
# Epoch 020/050 | Acc 62.500000  | Loss 0.955320: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 40.500000: 100%|████████████| 10/10 [00:05<00:00,  1.67it/s]
# Val Acc = 40.50% +- 4.07%
#
# Epoch 021/050 | Acc 64.250000  | Loss 0.900621: 100%|█| 10/10 [00:12<00:00,  1.3
# Validation    | Acc 40.500000: 100%|████████████| 10/10 [00:05<00:00,  1.67it/s]
# Val Acc = 40.50% +- 4.33%
#
# Epoch 022/050 | Acc 64.000000  | Loss 0.883590: 100%|█| 10/10 [00:12<00:00,  1.3
# Validation    | Acc 52.250000: 100%|████████████| 10/10 [00:05<00:00,  1.71it/s]
# Val Acc = 52.25% +- 3.73%
# best model! save...
#
# Epoch 023/050 | Acc 69.750000  | Loss 0.777963: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 47.375000: 100%|████████████| 10/10 [00:05<00:00,  1.76it/s]
# Val Acc = 47.38% +- 6.16%
#
# Epoch 024/050 | Acc 72.750000  | Loss 0.723281: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 45.375000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 45.38% +- 6.20%
#
# Epoch 025/050 | Acc 72.000000  | Loss 0.708064: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 53.375000: 100%|████████████| 10/10 [00:05<00:00,  1.82it/s]
# Val Acc = 53.38% +- 4.57%
# best model! save...
#
# Epoch 026/050 | Acc 77.875000  | Loss 0.612728: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 50.125000: 100%|████████████| 10/10 [00:05<00:00,  1.74it/s]
# Val Acc = 50.12% +- 6.05%
#
# Epoch 027/050 | Acc 79.875000  | Loss 0.568737: 100%|█| 10/10 [00:12<00:00,  1.3
# Validation    | Acc 49.500000: 100%|████████████| 10/10 [00:05<00:00,  1.73it/s]
# Val Acc = 49.50% +- 3.20%
#
# Epoch 028/050 | Acc 80.250000  | Loss 0.524168: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 51.375000: 100%|████████████| 10/10 [00:05<00:00,  1.71it/s]
# Val Acc = 51.38% +- 5.24%
#
# Epoch 029/050 | Acc 81.750000  | Loss 0.512951: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 47.375000: 100%|████████████| 10/10 [00:05<00:00,  1.76it/s]
# Val Acc = 47.38% +- 5.69%
#
# Epoch 030/050 | Acc 79.000000  | Loss 0.573971: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 55.125000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 55.12% +- 5.06%
# best model! save...
#
# Epoch 031/050 | Acc 81.625000  | Loss 0.508810: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 48.750000: 100%|████████████| 10/10 [00:06<00:00,  1.65it/s]
# Val Acc = 48.75% +- 4.53%
#
# Epoch 032/050 | Acc 84.500000  | Loss 0.433921: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 56.250000: 100%|████████████| 10/10 [00:05<00:00,  1.73it/s]
# Val Acc = 56.25% +- 5.54%
# best model! save...
#
# Epoch 033/050 | Acc 81.125000  | Loss 0.464943: 100%|█| 10/10 [00:12<00:00,  1.3
# Validation    | Acc 53.625000: 100%|████████████| 10/10 [00:05<00:00,  1.70it/s]
# Val Acc = 53.62% +- 6.41%
#
# Epoch 034/050 | Acc 84.000000  | Loss 0.417447: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 48.375000: 100%|████████████| 10/10 [00:05<00:00,  1.79it/s]
# Val Acc = 48.38% +- 4.60%
#
# Epoch 035/050 | Acc 82.000000  | Loss 0.447819: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 56.125000: 100%|████████████| 10/10 [00:05<00:00,  1.70it/s]
# Val Acc = 56.12% +- 5.95%
#
# Epoch 036/050 | Acc 86.625000  | Loss 0.342501: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 48.875000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 48.88% +- 4.35%
#
# Epoch 037/050 | Acc 87.000000  | Loss 0.374916: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 56.625000: 100%|████████████| 10/10 [00:05<00:00,  1.76it/s]
# Val Acc = 56.62% +- 5.31%
# best model! save...
#
# Epoch 038/050 | Acc 85.250000  | Loss 0.404696: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 56.750000: 100%|████████████| 10/10 [00:05<00:00,  1.70it/s]
# Val Acc = 56.75% +- 3.31%
# best model! save...
#
# Epoch 039/050 | Acc 85.375000  | Loss 0.380587: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 57.875000: 100%|████████████| 10/10 [00:05<00:00,  1.74it/s]
# Val Acc = 57.88% +- 6.28%
# best model! save...
#
# Epoch 040/050 | Acc 88.250000  | Loss 0.353298: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 57.375000: 100%|████████████| 10/10 [00:05<00:00,  1.74it/s]
# Val Acc = 57.38% +- 6.10%
#
# Epoch 041/050 | Acc 88.875000  | Loss 0.268047: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 55.125000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 55.12% +- 5.67%
#
# Epoch 042/050 | Acc 88.375000  | Loss 0.304987: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 53.125000: 100%|████████████| 10/10 [00:05<00:00,  1.69it/s]
# Val Acc = 53.12% +- 6.16%
#
# Epoch 043/050 | Acc 89.625000  | Loss 0.281975: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 52.125000: 100%|████████████| 10/10 [00:05<00:00,  1.77it/s]
# Val Acc = 52.12% +- 5.68%
#
# Epoch 044/050 | Acc 90.750000  | Loss 0.283020: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 58.000000: 100%|████████████| 10/10 [00:05<00:00,  1.76it/s]
# Val Acc = 58.00% +- 4.34%
# best model! save...
#
# Epoch 045/050 | Acc 89.375000  | Loss 0.302760: 100%|█| 10/10 [00:13<00:00,  1.3
# Validation    | Acc 53.875000: 100%|████████████| 10/10 [00:05<00:00,  1.67it/s]
# Val Acc = 53.88% +- 3.51%
#
# Epoch 046/050 | Acc 93.000000  | Loss 0.215592: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 58.125000: 100%|████████████| 10/10 [00:05<00:00,  1.75it/s]
# Val Acc = 58.12% +- 4.80%
# best model! save...
#
# Epoch 047/050 | Acc 88.750000  | Loss 0.301969: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 56.875000: 100%|████████████| 10/10 [00:05<00:00,  1.71it/s]
# Val Acc = 56.88% +- 5.35%
#
# Epoch 048/050 | Acc 91.875000  | Loss 0.226872: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 60.500000: 100%|████████████| 10/10 [00:05<00:00,  1.74it/s]
# Val Acc = 60.50% +- 4.27%
# best model! save...
#
# Epoch 049/050 | Acc 93.000000  | Loss 0.178748: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 54.625000: 100%|████████████| 10/10 [00:05<00:00,  1.76it/s]
# Val Acc = 54.62% +- 6.39%
#
# Epoch 050/050 | Acc 89.375000  | Loss 0.282133: 100%|█| 10/10 [00:12<00:00,  1.2
# Validation    | Acc 62.625000: 100%|████████████| 10/10 [00:05<00:00,  1.87it/s]
# Val Acc = 62.62% +- 6.06%
# best model! save...
#
# ===================================
# Test phase:
# Testing with file: /kaggle/working/Few-Shot-Cosine-Transformer/dataset/Yoga/novel.json
# Test loader contains 0 episodes
# WARNING: Test loader is empty! Check your data paths and configuration.
# ERROR: Test loader is empty
# 0 Test Acc = 0.00% +-  nan%
